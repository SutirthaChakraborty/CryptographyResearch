# %% [markdown]
# # **Download the GitRepo**

# %%
# !git clone https://github.com/SutirthaChakraborty/CryptographyResearch.git

# %% [markdown]
# **Run the FactorDriver.py**
#
# `Inputs`
#
#
# 1.   Large Integer Number
# 2.   Number of Trials
#
#
#
# *Example Number -*
#
#
# 187072209578355573530071658587684226515959365500927

# %%
# !python /content/CryptographyResearch/FactorDriver.py
# Out:
# Enter a big Number :: 187072209578355573530071658587684226515959365500927
# Enter number of Curves Per Go :: 33
# Curve  0  P is ( 22285482483011564159736746754405808888367806395735 ,  70116842013201724467478146753059871332502094454481 )
# Curve  0 A is  60013028627379316623922006640217003835914004198225  and C is  174638288838339221532186270713667811247423914385126
# Curve  1  P is ( 132798353244162296173813317069103778760107106609844 ,  182674081253429380779012693135262844877850098727070 )
# Curve  1 A is  23260650760353131465985681941516704480025262246786  and C is  51786773668525859800004285324841950399751155876626
# Curve  2  P is ( 26217701368263838971963890565764218729751546169988 ,  94203242785932358546101819537654667956657891436306 )
# Curve  2 A is  23429268769223376582135292680937324028664347346778  and C is  105325647413758294054403099983121990251183311942435
# ...

# %%
from google.colab import files
files.download('FactorDriver_output.txt')
